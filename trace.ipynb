# %%
import numpy as np
import glob
import matplotlib.pyplot as plt

# %%
trace = [
    dict(np.load(x))
    for x in 
    sorted(x for x in glob.glob(
        'saved/d2_h30_lr0.0005_llNone_dt0.01_beta10.0/*.npz'
    ) if not 'read' in x)
]

columns = trace[0].keys()

trace = {
    k: np.array([x[k] for x in trace]) for k in columns
}

for i in range(4):
    x = trace['rw'][:,i,0]
    y = trace['rw'][:,i,1]
    plt.plot(x, y, 'o--')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 16
#      11 trace = {
#      12     k: np.array([x[k] for x in trace]) for k in columns
#      13 }
#      15 for i in range(4):
# ---> 16     x = trace['rw'][:,i,0]
#      17     y = trace['rw'][:,i,1]
#      18     plt.plot(x, y, 'o--')
#
# IndexError: index 3 is out of bounds for axis 1 with size 3
